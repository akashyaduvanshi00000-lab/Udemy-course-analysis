# %% [markdown]
# # Udemy-course-analysis project

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r'udemy_courses.csv',parse_dates = ['published_timestamp'])
data
# Out:
#       course_id                                       course_title  \
# 0       1070968                 Ultimate Investment Banking Course
# 1       1113822  Complete GST Course & Certification - Grow You...
# 2       1006314  Financial Modeling for Business Analysts and C...
# 3       1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4       1011058       How To Maximize Your Profits Trading Options
# ...         ...                                                ...
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 0     https://www.udemy.com/ultimate-investment-bank...     True    200
# ...

# %%
data.dtypes
# Out:
# course_id                            int64
# course_title                        object
# url                                 object
# is_paid                               bool
# price                                int64
# num_subscribers                      int64
# num_reviews                          int64
# num_lectures                         int64
# level                               object
# content_duration                   float64
# published_timestamp    datetime64[ns, UTC]
# subject                             object
# dtype: object

# %%
# display top 10 rows of the dataset
data.head(10)
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
# 5     192870  Trading Penny Stocks: A Guide for All Levels I...
# 6     739964  Investing And Trading For Beginners: Mastering...
# 7     403100  Trading Stock Chart Patterns For Immediate, Ex...
# 8     476268  Options Trading 3 : Advanced Stock Profit and ...
# 9    1167710  The Only Investment Strategy You Need For Your...
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# ...

# %%
# Check Last 5 Rows of the dataset
data.tail()
# Out:
#       course_id                                       course_title  \
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 3673  https://www.udemy.com/easy-jquery-for-beginner...     True    100
# 3674  https://www.udemy.com/how-to-make-a-wordpress-...     True     25
# 3675  https://www.udemy.com/learn-and-build-using-po...     True     40
# 3676  https://www.udemy.com/css-animations-create-am...     True     50
# 3677  https://www.udemy.com/using-modx-cms-to-build-...     True     45
#
#       num_subscribers  num_reviews  num_lectures           level  \
# ...

# %%
# Find shape of our dataset (number of rows and number of columns)
print('Number of Rows',data.shape[0])
print('Numebr of Columns' ,data.shape[1])
# Out:
# Number of Rows 3678
# Numebr of Columns 12

# %%
# getting information about our dataset like total number rows,total number of columns, dataset of each column and money requirement
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3678 entries, 0 to 3677
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3678 non-null   int64
#  1   course_title         3678 non-null   object
#  2   url                  3678 non-null   object
#  3   is_paid              3678 non-null   bool
#  4   price                3678 non-null   int64
#  5   num_subscribers      3678 non-null   int64
#  6   num_reviews          3678 non-null   int64
#  7   num_lectures         3678 non-null   int64
#  8   level                3678 non-null   object
#  9   content_duration     3678 non-null   float64
#  10  published_timestamp  3678 non-null   datetime64[ns, UTC]
#  11  subject              3678 non-null   object
# dtypes: bool(1), datetime64[ns, UTC](1), float64(1), int64(5), object(4)
# memory usage: 319.8+ KB

# %%
# check null values in the dataset
data.isnull().sum()
# Out:
# course_id              0
# course_title           0
# url                    0
# is_paid                0
# price                  0
# num_subscribers        0
# num_reviews            0
# num_lectures           0
# level                  0
# content_duration       0
# published_timestamp    0
# subject                0
# dtype: int64

# %%
print('Any Missing Value?',data.isnull().values.any())
# Out:
# Any Missing Value? False

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
# check for duplicate data and drop them
dup=data.duplicated().any()
print('Are There any duplicated value in data?',dup)
# Out:
# Are There any duplicated value in data? True

# %%
len(data[data.duplicated()])
# Out:
# 6

# %%
data = data.drop_duplicates()

# %%
dup=data.duplicated().any()
print('Are There any duplicated value in data?',dup)
# Out:
# Are There any duplicated value in data? False

# %%
# Find out number of courses per subjects
data.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
data['subject'].value_counts()
# Out:
# subject
# Web Development        1199
# Business Finance       1191
# Musical Instruments     680
# Graphic Design          602
# Name: count, dtype: int64

# %%
sns.countplot(x='subject',data=data)
ax = sns.countplot(x='subject',data=data)
for bars in ax.containers:
   ax.bar_label(bars)
plt.xlabel('Subject')
plt.ylabel('Number of Courses For Subject')
plt.show()

# %%
# For Which levels, Udemy Courses Providing the Courses
data['level'].value_counts()
# Out:
# level
# All Levels            1925
# Beginner Level        1268
# Intermediate Level     421
# Expert Level            58
# Name: count, dtype: int64

# %%
sns.countplot(x='level',data=data)
# Out:
# <Axes: xlabel='level', ylabel='count'>

# %%
# displays the counts of paid and free courses
data.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
data['is_paid'].value_counts()
# Out:
# is_paid
# True     3362
# False     310
# Name: count, dtype: int64

# %%
sns.countplot(x='is_paid',data=data)
plt.xlabel('courses')
plt.ylabel('Number of Free and Paid ')
plt.show()

# %%
# which course has more lectures (Free Or Paid)?
data.head(1)
# Out:
#    course_id                        course_title  \
# 0    1070968  Ultimate Investment Banking Course
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
#
#    num_subscribers  num_reviews  num_lectures       level  content_duration  \
# 0             2147           23            51  All Levels               1.5
#
#         published_timestamp           subject
# 0 2017-01-18 20:58:58+00:00  Business Finance

# %%
data.groupby(['is_paid']).mean(numeric_only=True)
# Out:
#              course_id      price  num_subscribers  num_reviews  num_lectures  \
# is_paid
# False    691446.970968   0.000000     11533.951613   425.929032     21.416129
# True     674463.946163  72.198096      2421.270077   131.516359     41.866746
#
#          content_duration
# is_paid
# False            2.210753
# True             4.271584

# %%
# which courses have a higher number of subscribers free or paid?
data.groupby('is_paid')['num_subscribers'].mean()
# Out:
# is_paid
# False    11533.951613
# True      2421.270077
# Name: num_subscribers, dtype: float64

# %%
sns.barplot(x='is_paid',y='num_subscribers',data=data)
plt.show()

# %%
# which level has the highest number of subscribes?
data['num_subscribers'].max()
# Out:
# np.int64(268923)

# %%
data.groupby('level')['num_subscribers'].max()
# Out:
# level
# All Levels            268923
# Beginner Level        161029
# Expert Level            5172
# Intermediate Level     29167
# Name: num_subscribers, dtype: int64

# %%
ax = sns.barplot(x='level',y='num_subscribers',data=data,ci=0)
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_5604\1244642594.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 0)` for the same effect.
#
#   ax = sns.barplot(x='level',y='num_subscribers',data=data,ci=0)

# %%
# find most popular course title
data.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
data[data['num_subscribers'].max()==data['num_subscribers']]['course_title']
# Out:
# 2827    Learn HTML5 Programming From Scratch
# Name: course_title, dtype: object

# %%
data.groupby('num_subscribers')['course_title'].max()
# Out:
# num_subscribers
# 0                                      beginning accounting
# 1                                誰でもわかる Adobe Photoshop CS5
# 2                                      こどもギターレッスン　リトルギタリストⅡ
# 3                                                  会声会影深度教学
# 4                                                    调色高级讲解
#                                 ...
# 114512                The Complete Web Developer Course 2.0
# 120291    Build Your First Website in 1 Week with HTML5 ...
# 121584                           The Web Developer Bootcamp
# 161029                       Coding for Entrepreneurs Basic
# 268923                 Learn HTML5 Programming From Scratch
# Name: course_title, Length: 2197, dtype: object

# %%
data[data['num_subscribers']==268923]['course_title']
# Out:
# 2827    Learn HTML5 Programming From Scratch
# Name: course_title, dtype: object

# %%
# display 10 most popular courses As Per Number of Subscibers
data['num_subscribers'].sort_values(ascending=False).head(10)
# Out:
# 2827    268923
# 3032    161029
# 3230    121584
# 2783    120291
# 3232    114512
# 1896    101154
# 2589     98867
# 2619     84897
# 3289     83737
# 3247     79612
# Name: num_subscribers, dtype: int64

# %%
top10 = data.sort_values(by='num_subscribers',ascending=False).head(10)

# %%
sns.barplot(x='num_subscribers',y='course_title',data=top10)
plt.show()

# %%
# Find the course which is having the highest numbers of reviews.
data.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
data.groupby('subject')['num_reviews'].max()
# Out:
# subject
# Business Finance        4397
# Graphic Design          2379
# Musical Instruments     7676
# Web Development        27445
# Name: num_reviews, dtype: int64

# %%
data.groupby('subject')['num_reviews'].mean().sort_values(ascending=False)
# Out:
# subject
# Web Development        358.354167
# Business Finance        63.516318
# Graphic Design          61.475954
# Musical Instruments     46.652941
# Name: num_reviews, dtype: float64

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='subject',y='num_reviews',data=data)
plt.xticks(rotation=45)
plt.show()

# %%
# Does Price Affect Number of Reviews?
data.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
sns.scatterplot(x='price',y='num_reviews',data=data)
# Out:
# <Axes: xlabel='price', ylabel='num_reviews'>

# %%
# Find total number of courses related to python
len(data[data['course_title'].str.contains('Python',case=False)])
# Out:
# 29

# %%
# display 10 ,most popular python courses As of subscribers
data.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
python = data[data['course_title'].str.contains('Python',case=False)].sort_values(by='num_subscribers',ascending=False).head(10)

# %%
sns.barplot(x='num_subscribers',y='course_title',data=python)
plt.show()

# %%
# in which year the highest number of courses were posted?
data.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject', 'Year'],
#       dtype='object')

# %%
data['Year'] = data['published_timestamp'].dt.year

# %%
sns.countplot(x='Year',data=data)
plt.show()

# %%
# display category-wish count of posted subjects[year wise]
data.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject', 'Year'],
#       dtype='object')

# %%
data.groupby('Year')['subject'].value_counts()
# Out:
# Year  subject
# 2011  Web Development          5
# 2012  Web Development         19
#       Graphic Design          10
#       Musical Instruments     10
#       Business Finance         6
# 2013  Business Finance        84
#       Web Development         56
#       Musical Instruments     39
#       Graphic Design          23
# 2014  Business Finance       192
#       Musical Instruments    120
#       Web Development        113
#       Graphic Design          66
# 2015  Business Finance       339
#       Web Development        336
#       Musical Instruments    171
#       Graphic Design         168
# 2016  Web Development        448
#       Business Finance       349
#       Musical Instruments    228
#       Graphic Design         181
# 2017  Business Finance       225
#       Web Development        223
#       Graphic Design         155
#       Musical Instruments    112
# Name: count, dtype: int64
